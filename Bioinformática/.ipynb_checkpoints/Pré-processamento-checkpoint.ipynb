# %%
import numpy as np
import pandas as pd

# %%
ft = pd.read_csv(
    'transcriptors_matriz.txt',
    sep=',', header=None, names=['id', 'A', 'C', 'G', 'T'])
print(type(ft), ft.shape)
ft
# Out:
# <class 'pandas.core.frame.DataFrame'> (489, 5)
#                        id                                                  A  \
# 0         >MA0020.1\tDof2    A  [    21     21     21      0      3      7 ]
# 1         >MA0021.1\tDof3    A  [    21     21     21      0      0      6 ]
# 2         >MA0034.1\tGam1  A  [     4     10      3     23     25      1 ...
# 3        >MA0044.1\tHMG-1  A  [     0      0      0      0      0      6 ...
# 4      >MA0045.1\tHMG-I/Y  A  [     3      7      9      3     11     11 ...
# 5        >MA0053.1\tMNB1A           A  [    15     15     15      0      3 ]
# 6      >MA0054.1\tmyb.Ph3  A  [    19     64     63      4     10     10 ...
# 7          >MA0064.1\tPBF           A  [    16     16     16      0      1 ]
# 8     >MA0082.1\tsquamosa  A  [    11      0     24     16     23     17 ...
# 9      >MA0096.1\tbZIP910  A  [    15      0      0     35      0      0 ...
# 10     >MA0097.1\tbZIP911  A  [     1     17      0      0     33      0 ...
# ...

# %%
print(ft['A'][0])
print(ft['C'][0])
print(ft['G'][0])
print (ft['T'][0])
# Out:
# A  [    21     21     21      0      3      7 ]
# C  [     0      0      0      0     14      6 ]
# G  [     0      0      0     21      2      3 ]
# T  [     0      0      0      0      2      5 ]

# %%
def f_str_list (amn):
    aux = list (amn)
    listed = []
    for i in aux:
        number = 0
        if i>='0' and i<='9':
            number = int(i)
            """
            j=1
            while(aux[i+j]>='0' and aux[i+j]<='9'):
                number = number*10
                number = number+int(aux[i+j])
                j +=1
            """
            listed.append(number)
    
    return listed

# %%
print (f_str_list(ft['A'][0]))
# Out:
# [2, 1, 2, 1, 2, 1, 0, 3, 7]

# %%
result = ft['A'][0]
