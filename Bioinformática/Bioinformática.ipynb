# %%
import numpy as np
import pandas as pd

# %%
transcriptions = pd.read_csv('Transcription_factor_weight_matrix.txt', sep='>', header = None, names=['Matrix ID', 'Matrix'])

# %%
print (transcriptions.shape)
# Out:
# (5750, 2)

# %%
print (5750/5)
# Out:
# 1150.0

# %%
print (transcriptions)
# Out:
#                                               Matrix ID             Matrix
# 0                                                   NaN    TFmatrixID_0001
# 1     A\t[0.3651\t0.7719\t0.8431\t0.4837\t0.3315\t0....                NaN
# 2     C\t[0.0848\t0.0176\t0.0353\t0.0144\t0.0061\t0....                NaN
# 3     G\t[0.1309\t0.1464\t0.0236\t0.0047\t0.0029\t0....                NaN
# 4     T\t[0.4191\t0.0641\t0.0979\t0.4972\t0.6596\t0....                NaN
# 5                                                   NaN    TFmatrixID_0002
# 6     A\t[0.3438\t0.5527\t0.3738\t0.7858\t0.7384\t0....                NaN
# 7     C\t[0.094\t0.0233\t0.0187\t0.0039\t0.0022\t0.0...                NaN
# 8     G\t[0.4166\t0.0245\t0.0215\t0.0114\t0.0076\t0....                NaN
# 9     T\t[0.1457\t0.3994\t0.5859\t0.199\t0.2519\t0.7...                NaN
# 10                                                  NaN    TFmatrixID_0003
# ...

# %%
transcriptions = transcriptions.T

# %%
print (transcriptions)
# Out:
#                       0                                                  1     \
# Matrix ID              NaN  A\t[0.3651\t0.7719\t0.8431\t0.4837\t0.3315\t0....
# Matrix     TFmatrixID_0001                                                NaN
# 0                Matrix ID                                          Matrix ID
# (0, 0)     TFmatrixID_0001                                    TFmatrixID_0001
# (1, 0)     TFmatrixID_0001                                    TFmatrixID_0001
# (2, 0)           Matrix ID                                          Matrix ID
# (3, 0)           Matrix ID                                          Matrix ID
# (0, 1)     TFmatrixID_0001                                    TFmatrixID_0001
# (0, 2)     TFmatrixID_0001                                    TFmatrixID_0001
# (0, 3)     TFmatrixID_0001                                    TFmatrixID_0001
# (0, 4)     TFmatrixID_0001                                    TFmatrixID_0001
# ...
